# %% [markdown]
# This project builds a course recommendation system to help learners find relevant online courses.
#
# It uses content-based filtering to suggest similar courses and collaborative filtering to recommend top-rated ones.
#
# The system also evaluates prediction accuracy using RMSE and MAE to ensure reliable recommendations.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# We’re importing tools to handle data (pandas, numpy), scale numbers (MinMaxScaler), and measure similarity between courses (cosine_similarity).

# %%
# Load dataset
df = pd.read_excel("online_course_recommendation_v2.xlsx")
df
# Out:
#        user_id  course_id                           course_name  \
# 0        15796       9366                  Python for Beginners
# 1          861       1928       Cybersecurity for Professionals
# 2        38159       9541      DevOps and Continuous Deployment
# 3        44733       3708       Project Management Fundamentals
# 4        11285       3361           Ethical Hacking Masterclass
# ...        ...        ...                                   ...
# 99995    10647       5466             Graphic Design with Canva
# 99996    13800       2623   Stock Market and Trading Strategies
# 99997    47131       1556  Networking and System Administration
# 99998    49654       6001             Graphic Design with Canva
# 99999    12929       5763             Graphic Design with Canva
#
#             instructor  course_duration_hours certification_offered  \
# 0          Emma Harris                   39.1                   Yes
# 1      Alexander Young                   36.3                   Yes
# 2       Dr. Mia Walker                   13.4                   Yes
# 3       Benjamin Lewis                   58.3                   Yes
# 4         Daniel White                   30.8                   Yes
# ...                ...                    ...                   ...
# 99995      Emma Harris                   17.3                   Yes
# 99996   Dr. John Smith                   68.4                   Yes
# 99997   Dr. John Smith                   73.8                   Yes
# 99998     Daniel White                   30.3                   Yes
# 99999     Daniel White                   67.0                    No
#
#       difficulty_level  rating  enrollment_numbers  course_price  \
# 0             Beginner     5.0               21600        317.50
# 1             Beginner     4.3               15379         40.99
# 2             Beginner     3.9                6431        380.81
# 3             Beginner     3.1               48245        342.80
# 4             Beginner     2.8               34556        381.01
# ...                ...     ...                 ...           ...
# 99995         Beginner     3.9               49101        485.34
# 99996         Beginner     3.5               35107        162.80
# 99997         Beginner     4.3               12146         24.02
# 99998         Beginner     3.5                9933        402.24
# 99999         Beginner     2.3                3479        135.61
#
#        feedback_score study_material_available  time_spent_hours  \
# 0               0.797                      Yes             17.60
# 1               0.770                      Yes             28.97
# 2               0.772                      Yes             52.44
# 3               0.969                       No             22.29
# 4               0.555                      Yes             22.01
# ...               ...                      ...               ...
# 99995           0.838                      Yes             16.35
# 99996           0.922                      Yes             41.94
# 99997           0.990                      Yes             15.87
# 99998           0.630                      Yes             21.05
# 99999           0.753                      Yes              8.63
#
#        previous_courses_taken
# 0                           4
# 1                           9
# 2                           4
# 3                           6
# 4                           5
# ...                       ...
# 99995                       3
# 99996                       7
# 99997                       5
# 99998                       4
# 99999                       1
#
# [100000 rows x 14 columns]

# %% [markdown]
# This reads your Excel file into a table called df. It contains all course and user information.

# %%
# Drop unused columns to reduce memory
df = df[['user_id', 'course_id', 'course_name', 'instructor', 'difficulty_level',
         'course_duration_hours', 'certification_offered', 'study_material_available',
         'course_price', 'feedback_score', 'rating']]
df
# Out:
#        user_id  course_id                           course_name  \
# 0        15796       9366                  Python for Beginners
# 1          861       1928       Cybersecurity for Professionals
# 2        38159       9541      DevOps and Continuous Deployment
# 3        44733       3708       Project Management Fundamentals
# 4        11285       3361           Ethical Hacking Masterclass
# ...        ...        ...                                   ...
# 99995    10647       5466             Graphic Design with Canva
# 99996    13800       2623   Stock Market and Trading Strategies
# 99997    47131       1556  Networking and System Administration
# 99998    49654       6001             Graphic Design with Canva
# 99999    12929       5763             Graphic Design with Canva
#
#             instructor difficulty_level  course_duration_hours  \
# 0          Emma Harris         Beginner                   39.1
# 1      Alexander Young         Beginner                   36.3
# 2       Dr. Mia Walker         Beginner                   13.4
# 3       Benjamin Lewis         Beginner                   58.3
# 4         Daniel White         Beginner                   30.8
# ...                ...              ...                    ...
# 99995      Emma Harris         Beginner                   17.3
# 99996   Dr. John Smith         Beginner                   68.4
# 99997   Dr. John Smith         Beginner                   73.8
# 99998     Daniel White         Beginner                   30.3
# 99999     Daniel White         Beginner                   67.0
#
#       certification_offered study_material_available  course_price  \
# 0                       Yes                      Yes        317.50
# 1                       Yes                      Yes         40.99
# 2                       Yes                      Yes        380.81
# 3                       Yes                       No        342.80
# 4                       Yes                      Yes        381.01
# ...                     ...                      ...           ...
# 99995                   Yes                      Yes        485.34
# 99996                   Yes                      Yes        162.80
# 99997                   Yes                      Yes         24.02
# 99998                   Yes                      Yes        402.24
# 99999                    No                      Yes        135.61
#
#        feedback_score  rating
# 0               0.797     5.0
# 1               0.770     4.3
# 2               0.772     3.9
# 3               0.969     3.1
# 4               0.555     2.8
# ...               ...     ...
# 99995           0.838     3.9
# 99996           0.922     3.5
# 99997           0.990     4.3
# 99998           0.630     3.5
# 99999           0.753     2.3
#
# [100000 rows x 11 columns]

# %% [markdown]
# Keeps only relevant columns needed for recommendation.
#
# Reduces memory usage and simplifies processing

# %%
# Encode binary and categorical features
df['certification_offered'] = df['certification_offered'].map({'Yes': 1, 'No': 0})
df['certification_offered']
# Out:
# /tmp/ipython-input-4095392981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['certification_offered'] = df['certification_offered'].map({'Yes': 1, 'No': 0})
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    0
# Name: certification_offered, Length: 100000, dtype: int64

# %%
df['difficulty_level'] = df['difficulty_level'].map({'Beginner': 1, 'Intermediate': 2, 'Advanced': 3})
df['difficulty_level']
# Out:
# /tmp/ipython-input-1591384625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['difficulty_level'] = df['difficulty_level'].map({'Beginner': 1, 'Intermediate': 2, 'Advanced': 3})
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    1
# Name: difficulty_level, Length: 100000, dtype: int64

# %%
df['study_material_available'] = df['study_material_available'].map({'Yes': 1, 'No': 0})
df['study_material_available']
# Out:
# /tmp/ipython-input-63869326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['study_material_available'] = df['study_material_available'].map({'Yes': 1, 'No': 0})
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    1
# Name: study_material_available, Length: 100000, dtype: int64

# %% [markdown]
# We change words like "Yes"/"No" and "Beginner"/"Advanced" into numbers so the computer can understand and compare them

# %%
# Normalize numerical features
scaler = MinMaxScaler()
df[['course_duration_hours', 'course_price', 'feedback_score']] = scaler.fit_transform(
    df[['course_duration_hours', 'course_price', 'feedback_score']]
)
# Out:
# /tmp/ipython-input-1172061927.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['course_duration_hours', 'course_price', 'feedback_score']] = scaler.fit_transform(

# %% [markdown]
# We scale values like course duration and price to a range between 0 and 1. This helps avoid bias in similarity calculations.

# %%
# Content-based: course similarity matrix
course_features = df.drop_duplicates('course_id')[[
    'course_id', 'difficulty_level', 'course_duration_hours',
    'certification_offered', 'study_material_available',
    'course_price', 'feedback_score'
]].set_index('course_id')
course_features
# Out:
#            difficulty_level  course_duration_hours  certification_offered  \
# course_id
# 9366                      1               0.358947                      1
# 1928                      1               0.329474                      1
# 9541                      1               0.088421                      1
# 3708                      1               0.561053                      1
# 3361                      1               0.271579                      1
# ...                     ...                    ...                    ...
# 1570                      2               0.238947                      1
# 1629                      1               0.545263                      1
# 4445                      3               0.489474                      0
# 4004                      2               0.892632                      1
# 5636                      3               0.910526                      1
#
#            study_material_available  course_price  feedback_score
# course_id
# 9366                              1      0.619792        0.776432
# 1928                              1      0.043729        0.746696
# 9541                              1      0.751688        0.748899
# 3708                              0      0.672500        0.965859
# 3361                              1      0.752104        0.509912
# ...                             ...           ...             ...
# 1570                              1      0.871146        0.906388
# 1629                              1      0.497542        0.806167
# 4445                              1      0.914604        0.595815
# 4004                              1      0.014000        0.857930
# 5636                              1      0.226708        0.500000
#
# [9998 rows x 6 columns]

# %% [markdown]
# We create a table where each course has a unique set of features. This helps us compare courses to each other.

# %%
course_sim = cosine_similarity(course_features)
course_sim_df = pd.DataFrame(course_sim, index=course_features.index, columns=course_features.index)
course_sim_df
# Out:
# course_id      9366      1928      9541      3708      3361      8076  \
# course_id
# 9366       1.000000  0.958730  0.988930  0.863103  0.988362  0.842756
# 1928       0.958730  1.000000  0.929967  0.796828  0.926272  0.845556
# 9541       0.988930  0.929967  1.000000  0.838306  0.989135  0.819168
# 3708       0.863103  0.796828  0.838306  1.000000  0.829479  0.778594
# 3361       0.988362  0.926272  0.989135  0.829479  1.000000  0.847608
# ...             ...       ...       ...       ...       ...       ...
# 1570       0.950554  0.905672  0.953001  0.864462  0.949604  0.941275
# 1629       0.993963  0.969614  0.966818  0.867900  0.972544  0.848237
# 4445       0.758861  0.717520  0.753119  0.686590  0.767570  0.945822
# 4004       0.897098  0.938890  0.847981  0.821855  0.865419  0.953953
# 5636       0.828707  0.852006  0.794407  0.768167  0.824811  0.996257
#
# course_id      7887      2876      1578      4298  ...      7560      7580  \
# course_id                                          ...
# 9366       0.996928  0.626996  0.967013  0.901127  ...  0.820706  0.967786
# 1928       0.938041  0.603032  0.983419  0.926730  ...  0.762209  0.963018
# 9541       0.986369  0.545382  0.922211  0.878983  ...  0.831252  0.919849
# 3708       0.878981  0.770575  0.839393  0.784036  ...  0.709917  0.855823
# 3361       0.983843  0.573701  0.932849  0.897834  ...  0.816911  0.937407
# ...             ...       ...       ...       ...  ...       ...       ...
# 1570       0.945260  0.699296  0.901331  0.954787  ...  0.930707  0.898759
# 1629       0.989891  0.675670  0.987605  0.906271  ...  0.801204  0.989399
# 4445       0.753883  0.776991  0.726576  0.893037  ...  0.966710  0.730860
# 4004       0.878712  0.801983  0.948223  0.975089  ...  0.834442  0.938401
# 5636       0.807643  0.790860  0.856410  0.980543  ...  0.866698  0.849554
#
# course_id      3014      964       90        1570      1629      4445  \
# course_id
# 9366       0.715655  0.829823  0.749937  0.950554  0.993963  0.758861
# 1928       0.749220  0.778312  0.742832  0.905672  0.969614  0.717520
# 9541       0.709541  0.776376  0.725694  0.953001  0.966818  0.753119
# 3708       0.629202  0.714208  0.838413  0.864462  0.867900  0.686590
# 3361       0.695004  0.793805  0.743251  0.949604  0.972544  0.767570
# ...             ...       ...       ...       ...       ...       ...
# 1570       0.867567  0.815818  0.887326  1.000000  0.935380  0.904752
# 1629       0.713391  0.855073  0.757087  0.935380  1.000000  0.751269
# 4445       0.949876  0.816719  0.901216  0.904752  0.751269  1.000000
# 4004       0.866480  0.839796  0.896098  0.923271  0.922437  0.857893
# 5636       0.912378  0.783123  0.952104  0.921347  0.842854  0.929970
#
# course_id      4004      5636
# course_id
# 9366       0.897098  0.828707
# 1928       0.938890  0.852006
# 9541       0.847981  0.794407
# 3708       0.821855  0.768167
# 3361       0.865419  0.824811
# ...             ...       ...
# 1570       0.923271  0.921347
# 1629       0.922437  0.842854
# 4445       0.857893  0.929970
# 4004       1.000000  0.967117
# 5636       0.967117  1.000000
#
# [9998 rows x 9998 columns]

# %% [markdown]
# We calculate how similar each course is to every other course. The result is a matrix of similarity scores.

# %%
# Collaborative: average ratings per course
course_avg = df.groupby('course_id')['rating'].mean()
course_avg
# Out:
# course_id
# 1       3.972727
# 2       4.125000
# 3       3.950000
# 4       3.722222
# 5       3.866667
#           ...
# 9995    3.962500
# 9996    3.700000
# 9997    3.838462
# 9998    4.166667
# 9999    3.816667
# Name: rating, Length: 9998, dtype: float64

# %% [markdown]
# We find the average rating for each course. This helps us recommend top-rated courses

# %%
# Content-based recommendation
def recommend_similar_courses(course_id, top_n=5):
    if course_id not in course_sim_df.index:
        return "Course not found."
    similar = course_sim_df[course_id].sort_values(ascending=False)[1:top_n+1]
    return df[df['course_id'].isin(similar.index)][['course_name', 'instructor', 'difficulty_level']]

# %% [markdown]
# This function finds courses that are most similar to the one you liked, based on features like difficulty and price

# %%
# Collaborative recommendation
def recommend_top_courses(user_id, top_n=5):
    rated = df[df['user_id'] == user_id]['course_id'].tolist()
    unrated = course_avg[~course_avg.index.isin(rated)].sort_values(ascending=False).head(top_n)
    return df[df['course_id'].isin(unrated.index)][['course_name', 'instructor', 'difficulty_level']]

# %% [markdown]
# This function recommends top-rated courses that the user hasn’t rated yet. It’s based on what others liked.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Accuracy Evaluation (Collaborative baseline using course_avg)
def evaluate_accuracy():
    test_df = df.sample(frac=0.2, random_state=42)
    test_df['predicted_rating'] = test_df['course_id'].map(course_avg)
    test_df = test_df.dropna(subset=['predicted_rating'])

    rmse = np.sqrt(mean_squared_error(test_df['rating'], test_df['predicted_rating']))
    mae = mean_absolute_error(test_df['rating'], test_df['predicted_rating'])

    print(f"📊 Accuracy Evaluation:\nRMSE: {rmse:.3f}\nMAE: {mae:.3f}")

# Run evaluation
evaluate_accuracy()
# Out:
# 📊 Accuracy Evaluation:
# RMSE: 0.700
# MAE: 0.571

# %% [markdown]
# This function checks how close our predicted ratings are to actual ratings. Lower RMSE and MAE means better accuracy.

# %%
# Content-based: similar to course_id = 101
print(recommend_similar_courses(course_id=101))

# Collaborative: top courses for user_id = 5
print(recommend_top_courses(user_id=5))
# Out:
#                                      course_name        instructor  \
# 23             Mobile App Development with Swift         Sarah Lee
# 282          Stock Market and Trading Strategies    Benjamin Lewis
# 1420                 Ethical Hacking Masterclass         Sarah Lee
# 3657                        Python for Beginners    Isabella Scott
# 11641            Project Management Fundamentals    Charlotte King
# 12567            Cybersecurity for Professionals    Benjamin Lewis
# 12810          Mobile App Development with Swift         Sarah Lee
# 17459           DevOps and Continuous Deployment    Charlotte King
# 25250             Fitness and Nutrition Coaching    William Thomas
# 27189              Photography and Video Editing     Olivia Taylor
# 27416          Mobile App Development with Swift   Sophia Anderson
# 27680                    Public Speaking Mastery        Ethan Hall
# 31965                Game Development with Unity    William Thomas
# 32383            Cybersecurity for Professionals       Emma Harris
# 32988           DevOps and Continuous Deployment    Isabella Scott
# 40942          Mobile App Development with Swift    Isabella Scott
# 41794          Mobile App Development with Swift    William Thomas
# 44697       Personal Finance and Wealth Building    Isabella Scott
# 45270        Stock Market and Trading Strategies    Isabella Scott
# 45403          Fundamentals of Digital Marketing       Emma Harris
# 46494       Networking and System Administration    William Thomas
# 46546          Mobile App Development with Swift    Charlotte King
# 46987       Personal Finance and Wealth Building  Dr. Robert Davis
# 47666           DevOps and Continuous Deployment        Ethan Hall
# 48739                Ethical Hacking Masterclass    Charlotte King
# 51684                    AI for Business Leaders  Dr. Robert Davis
# 55273              Photography and Video Editing    Benjamin Lewis
# 56997  Blockchain and Decentralized Applications       Emma Harris
# 60355  Blockchain and Decentralized Applications    Benjamin Lewis
# 62387                Game Development with Unity         Sarah Lee
# 66196                Ethical Hacking Masterclass       Emma Harris
# 67000             Fitness and Nutrition Coaching    Isabella Scott
# 68102                    AI for Business Leaders        Liam Adams
# 74002            Cybersecurity for Professionals     Michael Brown
# 76554                Ethical Hacking Masterclass  Dr. Robert Davis
# 77302            Data Visualization with Tableau   Sophia Anderson
# 77753                 Cloud Computing Essentials    William Thomas
# 77760       Networking and System Administration   Sophia Anderson
# 81903                    AI for Business Leaders  Jessica Martinez
# 82633             Fitness and Nutrition Coaching    Dr. Mia Walker
# 82917                  Advanced Machine Learning    Dr. John Smith
# 87157                Ethical Hacking Masterclass     Michael Brown
# 87474          Mobile App Development with Swift    William Thomas
# 89343          Fundamentals of Digital Marketing     Michael Brown
# 92716              Photography and Video Editing    William Thomas
# 93355                Ethical Hacking Masterclass   Sophia Anderson
# 94620                Game Development with Unity    Isabella Scott
# 95957                 Cloud Computing Essentials   Sophia Anderson
#
#        difficulty_level
# 23                    2
# 282                   3
# 1420                  2
# 3657                  2
# 11641                 3
# 12567                 2
# 12810                 2
# 17459                 1
# 25250                 2
# 27189                 2
# 27416                 1
# 27680                 3
# 31965                 1
# 32383                 3
# 32988                 2
# 40942                 1
# 41794                 1
# 44697                 1
# 45270                 3
# 45403                 3
# 46494                 1
# 46546                 2
# 46987                 2
# 47666                 1
# 48739                 2
# 51684                 3
# 55273                 3
# 56997                 1
# 60355                 3
# 62387                 2
# 66196                 3
# 67000                 2
# 68102                 1
# 74002                 3
# 76554                 2
# 77302                 3
# 77753                 1
# 77760                 1
# 81903                 1
# 82633                 2
# 82917                 2
# 87157                 3
# 87474                 1
# 89343                 1
# 92716                 3
# 93355                 2
# 94620                 1
# 95957                 1
#                                course_name           instructor  \
# 4034       Data Visualization with Tableau        Michael Brown
# 6697       Project Management Fundamentals       William Thomas
# 18256      Data Visualization with Tableau  Prof. Emily Johnson
# 18570        Photography and Video Editing          Emma Harris
# 41956      Data Visualization with Tableau          Emma Harris
# 42066      Cybersecurity for Professionals         David Wilson
# 55686    Mobile App Development with Swift       William Thomas
# 62980              Public Speaking Mastery        Michael Brown
# 64587              Public Speaking Mastery       Isabella Scott
# 67885              Public Speaking Mastery           Ethan Hall
# 78168  Stock Market and Trading Strategies         David Wilson
# 79152           Cloud Computing Essentials           Ethan Hall
# 80167     DevOps and Continuous Deployment     Dr. Robert Davis
# 81815          Ethical Hacking Masterclass          James Clark
# 94252                 Python for Beginners         David Wilson
# 98767          Game Development with Unity        Michael Brown
#
#        difficulty_level
# 4034                  2
# 6697                  2
# 18256                 3
# 18570                 1
# 41956                 2
# 42066                 2
# 55686                 3
# 62980                 3
# 64587                 1
# 67885                 2
# 78168                 2
# 79152                 1
# 80167                 2
# 81815                 2
# 94252                 1
# 98767                 1

# %% [markdown]
# We test the accuracy and print recommendations for a sample course and user.
